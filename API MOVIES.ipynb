# %%
import numpy as np
import pandas as pd
import urllib.request, urllib.parse, urllib.error
import requests
import json
import time
import os
URL1 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
URL1 = requests.get(URL1).json()
print (URL1)
# Out:
# {'page': 1, 'total_results': 6358, 'total_pages': 318, 'results': [{'popularity': 16.797, 'vote_count': 2101, 'video': False, 'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg', 'id': 19404, 'adult': False, 'backdrop_path': '/mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg', 'original_language': 'hi', 'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'genre_ids': [35, 18, 10749], 'title': 'Dilwale Dulhania Le Jayenge', 'vote_average': 8.9, 'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.', 'release_date': '1995-10-20'}, {'popularity': 30.766, 'vote_count': 13676, 'video': False, 'poster_path': '/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg', 'id': 278, 'adult': False, '
# ...

# %%
URL1.keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
DF1 = pd.DataFrame(URL1['results'])

# %%
DF1.head()
# Out:
#    adult                     backdrop_path        genre_ids      id  \
# 0  False  /mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg  [35, 18, 10749]   19404
# 1  False  /j9XKiZrVeViAixVRzCta7h1VU9W.jpg         [80, 18]     278
# 2  False  /6xKCYgH16UuwEGAyroLU6p8HLIn.jpg         [80, 18]     238
# 3  False  /cM0pnzCF6T7u1AAEYgyCG6Sua6k.jpg     [35, 18, 53]  496243
# 4  False  /nvsdKYPKwf51EAgC0xLJMB9kUZM.jpg  [16, 18, 10749]  372058
#
#   original_language                original_title  \
# 0                hi  दिलवाले दुल्हनिया ले जायेंगे
# 1                en      The Shawshank Redemption
# 2                en                 The Godfather
# 3                ko                           기생충
# 4                ja                         君の名は。
#
#                                             overview  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      16.797
# 1  Framed in the 1940s for the double murder of h...      30.766
# ...

# %%
DF1.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
DF1.head()
# Out:
#        id                                           overview  popularity  \
# 0   19404  Raj is a rich, carefree, happy-go-lucky second...      16.797
# 1     278  Framed in the 1940s for the double murder of h...      30.766
# 2     238  Spanning the years 1945 to 1955, a chronicle o...      28.390
# 3  496243  All unemployed, Ki-taek's family takes peculia...      42.412
# 4  372058  High schoolers Mitsuha and Taki are complete s...      25.374
#
#   release_date                        title  vote_average
# 0   1995-10-20  Dilwale Dulhania Le Jayenge           8.9
# 1   1994-09-23     The Shawshank Redemption           8.7
# 2   1972-03-15                The Godfather           8.6
# 3   2019-10-11                     Parasite           8.6
# 4   2017-04-07                   Your Name.           8.6

# %%
URL2 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=2"
URL2 = requests.get(URL2).json()
DF2 = pd.DataFrame(URL2['results'])
DF2.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
DF2.head()
# Out:
#       id                                           overview  popularity  \
# 0    769  The true story of Henry Hill, a half-Irish, ha...      22.090
# 1    311  A former Prohibition-era Jewish gangster retur...      15.278
# 2  11216  A filmmaker recalls his childhood, when he fel...      10.145
# 3    346  A samurai answers a village's request for prot...      13.477
# 4    510  While serving time for insanity at a state men...      19.960
#
#   release_date                            title  vote_average
# 0   1990-09-19                       GoodFellas           8.4
# 1   1984-06-01      Once Upon a Time in America           8.4
# 2   2002-06-14                  Cinema Paradiso           8.4
# 3   1956-11-19                    Seven Samurai           8.4
# 4   1975-11-18  One Flew Over the Cuckoo's Nest           8.4

# %%
URL3 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=3"
URL3 = requests.get(URL3).json()
DF3 = pd.DataFrame(URL3['results'])
DF3.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL4 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=4"
URL4 = requests.get(URL4).json()
DF4 = pd.DataFrame(URL4['results'])
DF4.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL5 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=5"
URL5 = requests.get(URL5).json()
DF5 = pd.DataFrame(URL5['results'])
DF5.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL6 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=6"
URL6 = requests.get(URL6).json()
DF6 = pd.DataFrame(URL6['results'])
DF6.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL7 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=7"
URL7 = requests.get(URL7).json()
DF7 = pd.DataFrame(URL7['results'])
DF7.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL8 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=8"
URL8 = requests.get(URL8).json()
DF8 = pd.DataFrame(URL8['results'])
DF8.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL9 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=9"
URL9 = requests.get(URL9).json()
DF9 = pd.DataFrame(URL9['results'])
DF9.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
URL10 = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10"
URL10 = requests.get(URL10).json()
DF10 = pd.DataFrame(URL10['results'])
DF10.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
DF=pd.concat([DF1, DF2, DF3, DF4, DF5, DF6, DF7, DF8, DF9, DF10])

# %%
DF.head()
# Out:
#        id                                           overview  popularity  \
# 0   19404  Raj is a rich, carefree, happy-go-lucky second...      16.797
# 1     278  Framed in the 1940s for the double murder of h...      30.766
# 2     238  Spanning the years 1945 to 1955, a chronicle o...      28.390
# 3  496243  All unemployed, Ki-taek's family takes peculia...      42.412
# 4  372058  High schoolers Mitsuha and Taki are complete s...      25.374
#
#   release_date                        title  vote_average
# 0   1995-10-20  Dilwale Dulhania Le Jayenge           8.9
# 1   1994-09-23     The Shawshank Redemption           8.7
# 2   1972-03-15                The Godfather           8.6
# 3   2019-10-11                     Parasite           8.6
# 4   2017-04-07                   Your Name.           8.6

# %%
DF.info
# Out:
# <bound method DataFrame.info of         id                                           overview  popularity  \
# 0    19404  Raj is a rich, carefree, happy-go-lucky second...      16.797
# 1      278  Framed in the 1940s for the double murder of h...      30.766
# 2      238  Spanning the years 1945 to 1955, a chronicle o...      28.390
# 3   496243  All unemployed, Ki-taek's family takes peculia...      42.412
# 4   372058  High schoolers Mitsuha and Taki are complete s...      25.374
# 5      424  The true story of how businessman Oskar Schind...      24.831
# 6      240  In the continuing saga of the Corleone crime f...      25.065
# 7      129  A young girl, Chihiro, becomes trapped in a st...      28.033
# 8      497  A supernatural tale set on death row in a Sout...      18.739
# 9      637  A touching story of an Italian book seller of ...      17.761
# 10     680  A burger-loving hit man, his philosophical par...      32.587
# ...
